# %%
password = "Tatatatam"
name = "Selçuk"
a = input("Enter your first name please: ").title()
if a == name:
  print ("The password is:", password)
else:
  print ("Hello, {}! See you later.".format(a))
# Out:
# Enter your first name please: Selçuk
# The password is: Tatatatam
